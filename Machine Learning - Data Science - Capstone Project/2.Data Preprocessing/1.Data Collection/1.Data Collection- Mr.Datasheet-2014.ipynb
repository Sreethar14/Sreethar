# %%
#Import The Libraries

# %%
import pandas as pd

# %%
dataset=pd.read_csv("mr_datasheet2014.csv")

# %%
dataset
# Out:
#     District_Name  Crop/Year Winter/Summer          Rice  Area_Hectares  \
# 0      AURANGABAD       2014   Kharif          Arhar/Tur          32900
# 1      AURANGABAD       2014   Kharif              Bajra          45300
# 2      AURANGABAD       2014   Kharif       Cotton(lint)         101675
# 3      AURANGABAD       2014   Kharif          Groundnut           4100
# 4      AURANGABAD       2014   Kharif              Jowar           3700
# ..            ...        ...           ...           ...            ...
# 146     OSMANABAD       2014   Rabi                Wheat          24100
# 147     OSMANABAD       2014   Summer          Groundnut           1900
# 148     OSMANABAD       2014   Summer              Maize           1300
# 149     OSMANABAD       2014   Summer          Sunflower            500
# 150     OSMANABAD       2014   Whole Year      Sugarcane          39800
#
#      Production_Tonnes
# 0               8700.0
# 1              24200.0
# 2              61475.0
# ...

# %%
#Mr.Datasheet 2014(Crop/Year, Production)
#Mr.Datasheet 2014, "Data" refers to the identification of a Crop/Year or condition based on its Areo of Hectares and Production_Tonnes

# %%
#Attribute Information:

#A) District_Name (mean of distances from center to points on the perimeter)

#B) Crop_Year (standard deviation of gray-scale values)

#C) Weather (based on pedict whether the climate changes)

#D) Rice (mean of cultivation depends upon the climate condition)

#E) Area_Hectares (local variation in radius lengths)

#F) Production_Tonnes ( based on Crop/Year to diiferentiat the production)
