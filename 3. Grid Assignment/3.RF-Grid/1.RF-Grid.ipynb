# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.89108031, -0.02782381, -0.0755796 ,  1.01127431, -0.49929923],
#        [ 0.5336223 , -0.18898509, -0.0755796 , -0.98885138, -0.49929923],
#        [ 0.6051139 ,  1.58378898,  0.75672907,  1.01127431,  2.00280702],
#        ...,
#        [-1.46814257,  0.61682131,  0.75672907, -0.98885138,  2.00280702],
#        [-0.82471815,  0.45566003,  1.58903774,  1.01127431, -0.49929923],
#        [ 0.89108031,  1.26146642,  0.75672907, -0.98885138, -0.49929923]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2'],
           'n_estimators':[10,50,80,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\sreet\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 80, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 80}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.046296      0.000374         0.007837        0.004600
# 1        0.206984      0.005499         0.006908        0.006211
# 2        0.312371      0.010037         0.009488        0.007783
# 3        0.380265      0.004400         0.016109        0.002421
# 4        0.041017      0.004322         0.001916        0.002383
# 5        0.196457      0.010502         0.006013        0.007370
# 6        0.304528      0.004055         0.012135        0.006108
# 7        0.392683      0.005164         0.012268        0.003521
# 8        0.040645      0.006119         0.006409        0.006638
# 9        0.193390      0.005959         0.011207        0.009175
# 10       0.310662      0.004634         0.013708        0.005877
# 11       0.383665      0.006745         0.017525        0.006685
# 12       0.043557      0.004351         0.000000        0.000000
# 13       0.190597      0.006347         0.013993        0.003265
# 14       0.308839      0.006301         0.013263        0.001707
# 15       0.379727      0.008131         0.018297        0.002865
# 16       0.101533      0.009557         0.004854        0.004513
# 17       0.473707      0.019973         0.010481        0.006589
# 18       0.736448      0.007597         0.009245        0.007552
# 19       0.924694      0.010962         0.015359        0.000406
# 20       0.092162      0.005972         0.004869        0.006195
# 21       0.466492      0.013191         0.004459        0.006151
# 22       0.748078      0.006887         0.011967        0.006473
# 23       0.929460      0.011047         0.016360        0.001887
# 24       0.086457      0.059152         0.002216        0.004432
# 25       0.202453      0.004587         0.010836        0.003317
# 26       0.333565      0.005045         0.016456        0.006065
# 27       0.418046      0.009101         0.017211        0.006292
# 28       0.043093      0.006121         0.005613        0.006893
# 29       0.213427      0.006884         0.009951        0.006230
# 30       0.337348      0.003751         0.010814        0.006343
# 31       0.402378      0.017162         0.014793        0.001712
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                 80
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                 50
# 6    squared_error               log2                 80
# 7    squared_error               log2                100
# 8     friedman_mse               sqrt                 10
# 9     friedman_mse               sqrt                 50
# 10    friedman_mse               sqrt                 80
# 11    friedman_mse               sqrt                100
# 12    friedman_mse               log2                 10
# 13    friedman_mse               log2                 50
# 14    friedman_mse               log2                 80
# 15    friedman_mse               log2                100
# 16  absolute_error               sqrt                 10
# 17  absolute_error               sqrt                 50
# 18  absolute_error               sqrt                 80
# 19  absolute_error               sqrt                100
# 20  absolute_error               log2                 10
# 21  absolute_error               log2                 50
# 22  absolute_error               log2                 80
# 23  absolute_error               log2                100
# 24         poisson               sqrt                 10
# 25         poisson               sqrt                 50
# 26         poisson               sqrt                 80
# 27         poisson               sqrt                100
# 28         poisson               log2                 10
# 29         poisson               log2                 50
# 30         poisson               log2                 80
# 31         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.781527
# 1   {'criterion': 'squared_error', 'max_features':...           0.796602
# 2   {'criterion': 'squared_error', 'max_features':...           0.802866
# 3   {'criterion': 'squared_error', 'max_features':...           0.804153
# 4   {'criterion': 'squared_error', 'max_features':...           0.782195
# 5   {'criterion': 'squared_error', 'max_features':...           0.807489
# 6   {'criterion': 'squared_error', 'max_features':...           0.811747
# 7   {'criterion': 'squared_error', 'max_features':...           0.806450
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.802846
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.800777
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.813837
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.807897
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.814054
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.802155
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.808454
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.804117
# 16  {'criterion': 'absolute_error', 'max_features'...           0.786945
# 17  {'criterion': 'absolute_error', 'max_features'...           0.809083
# 18  {'criterion': 'absolute_error', 'max_features'...           0.804992
# 19  {'criterion': 'absolute_error', 'max_features'...           0.804755
# 20  {'criterion': 'absolute_error', 'max_features'...           0.794105
# 21  {'criterion': 'absolute_error', 'max_features'...           0.804170
# 22  {'criterion': 'absolute_error', 'max_features'...           0.808433
# 23  {'criterion': 'absolute_error', 'max_features'...           0.807673
# 24  {'criterion': 'poisson', 'max_features': 'sqrt...           0.779736
# 25  {'criterion': 'poisson', 'max_features': 'sqrt...           0.796673
# 26  {'criterion': 'poisson', 'max_features': 'sqrt...           0.810154
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.805370
# 28  {'criterion': 'poisson', 'max_features': 'log2...           0.772249
# 29  {'criterion': 'poisson', 'max_features': 'log2...           0.796928
# 30  {'criterion': 'poisson', 'max_features': 'log2...           0.801828
# 31  {'criterion': 'poisson', 'max_features': 'log2...           0.808441
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0